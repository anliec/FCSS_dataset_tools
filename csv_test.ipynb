# %%
from src.pair_reader import *

# %%
df = file_pair_reader("/cs-share/pradalier/lake/view_set/140904/poses_140904_160201.txt")
print(df.dtypes)
# Out:
# 140904_160201
# ['140904', '160201']
# dir1      int64
# file1     int64
# dir2      int64
# file2     int64
# date1    object
# date2    object
# dtype: object

# %%
dfl = load_files(["/cs-share/pradalier/lake/view_set/140904/poses_140904_160201.txt"])
print(dfl)
# Out:
# 140904_160201
# ['140904', '160201']
#      dir1  file1  dir2  file2   date1   date2
# 0       2    900    47    340  140904  160201
# 1       2    960    47    360  140904  160201
# 2       3    140    47    640  140904  160201
# 3       3    380    47    760  140904  160201
# 4       3    680    48      0  140904  160201
# 5       3    740    48     80  140904  160201
# 6       3    960    48    180  140904  160201
# 7       4    240     1    840  140904  160201
# 8       4    440     2    100  140904  160201
# 9       4    800     2    400  140904  160201
# 10      4    960     2    480  140904  160201
# 11      5    320     2    880  140904  160201
# 12      5    380     2    960  140904  160201
# 13      5    920     3    380  140904  160201
# 14      6    440     3    880  140904  160201
# 15      6    580     3    900  140904  160201
# 16      6    900     4    280  140904  160201
# 17      7    240     4    640  140904  160201
# 18      7    480     4    900  140904  160201
# 19      7    660     5     60  140904  160201
# 20      7    940     5    520  140904  160201
# 21      8    160     5    560  140904  160201
# 22      8    680     6     40  140904  160201
# 23      8    860     6    300  140904  160201
# 24      9     80     6    480  140904  160201
# 25      9    320     6    780  140904  160201
# 26      9    360     6    860  140904  160201
# 27      9    460     6    940  140904  160201
# 28      9    680     7    100  140904  160201
# 29      9    940     7    440  140904  160201
# ..    ...    ...   ...    ...     ...     ...
# 144    39    780    35    980  140904  160201
# 145    39    900    36    140  140904  160201
# 146    40    720    36    660  140904  160201
# 147    40    840    36    660  140904  160201
# 148    41    600    37    220  140904  160201
# 149    42    380    37    460  140904  160201
# 150    42    920    37    760  140904  160201
# 151    43     20    37    840  140904  160201
# 152    43    400    37    960  140904  160201
# 153    43    860    38    220  140904  160201
# 154    44     60    38    340  140904  160201
# 155    44    380    38    560  140904  160201
# 156    44    580    38    740  140904  160201
# 157    44    800    38    860  140904  160201
# 158    45    100    39    160  140904  160201
# 159    45    660    39    840  140904  160201
# 160    46    120    40    360  140904  160201
# 161    46    480    40    520  140904  160201
# 162    47    140    42     60  140904  160201
# 163    47    500    42    680  140904  160201
# 164    48    300    44    500  140904  160201
# 165    48    600    44    740  140904  160201
# 166    48    900    45     60  140904  160201
# 167    49    440    45    440  140904  160201
# 168    49    860    45    500  140904  160201
# 169    49    940    45    660  140904  160201
# 170    50    160    45    840  140904  160201
# 171    50    240    45    900  140904  160201
# 172    50    460    46    120  140904  160201
# 173    50    560    46    220  140904  160201
#
# [174 rows x 6 columns]
# 174
